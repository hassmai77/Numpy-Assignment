# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image as im

for i in range(20):
    img=mpimg.imread('C:\\Users\\Haroon Traders\\Desktop\\PIAIC\\images\\'+str(i+1)+'.jpg')
    imgplot = plt.imshow(img)
    plt.show()

list1=[]
for i in range(20):
    im1=(im.open('C:\\Users\\Haroon Traders\\Desktop\\PIAIC\\images\\'+str(i+1)+'.jpg'))
    im1=im1.resize((500,500),im.ANTIALIAS)
 #   print(plt.imshow(im1))
    im1.save('resize'+str(i+1)+'.jpg')
    list1.append(np.array(im1))
#    print(a1)
print(list1[19])
# Out:
# [[[191 218 223]
#   [118 149 177]
#   [103 143 192]
#   ...
#   [ 54  90 138]
#   [ 56  92 140]
#   [ 58  94 142]]
#
#  [[194 221 226]
#   [122 153 181]
#   [107 147 196]
#   ...
#   [ 54  90 138]
#   [ 57  93 141]
#   [ 61  97 145]]
#
#  [[196 223 228]
#   [125 156 184]
#   [111 151 200]
#   ...
#   [ 52  88 136]
#   [ 59  95 143]
#   [ 62  98 146]]
#
#  ...
#
#  [[176 197 203]
#   [ 63  92 109]
#   [ 80 119 148]
#   ...
#   [ 86 117 164]
#   [ 88 119 166]
#   [ 90 121 168]]
#
#  [[177 199 204]
#   [ 67  96 112]
#   [ 73 112 141]
#   ...
#   [ 83 114 161]
#   [ 90 121 168]
#   [ 84 115 162]]
#
#  [[181 203 208]
#   [ 75 104 120]
#   [ 65 104 135]
#   ...
#   [ 80 111 158]
#   [ 87 118 165]
#   [ 76 107 154]]]
